# %%
# %cd C:\Users\USER\OneDrive - 國立陽明交通大學\文件\academic\專題\env\rl-environment
# Out:
# C:\Users\USER\OneDrive - 國立陽明交通大學\文件\academic\專題\env\rl-environment

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
match_1 = pd.read_excel('match_data.xlsx')
match_2 = pd.read_excel('match_data_1.xlsx')

# %%
ball_location_x_diff = match_2['ball_location_x'] - match_1['ball_location_x']
sns.histplot(ball_location_x_diff)
# Out:
# <AxesSubplot:xlabel='ball_location_x', ylabel='Count'>

# %%
ball_location_y_diff = match_2['ball_location_y'] - match_1['ball_location_y']
sns.histplot(ball_location_y_diff)
# Out:
# <AxesSubplot:xlabel='ball_location_y', ylabel='Count'>

# %%
ball_height_diff = match_2['ball_height'] - match_1['ball_height']
sns.histplot(ball_height_diff)
# Out:
# <AxesSubplot:xlabel='ball_height', ylabel='Count'>

# %%
playerA_location_X = match_2['playerA_location_x'] - match_1['playerA_location_x']
sns.histplot(playerA_location_X)
# Out:
# <AxesSubplot:xlabel='playerA_location_x', ylabel='Count'>

# %%
playerA_location_y = match_2['playerA_location_y'] - match_1['playerA_location_y']
sns.histplot(playerA_location_y)
# Out:
# <AxesSubplot:xlabel='playerA_location_y', ylabel='Count'>

# %%
playerB_location_X = match_2['playerB_location_x'] - match_1['playerB_location_x']
sns.histplot(playerB_location_X)
# Out:
# <AxesSubplot:xlabel='playerB_location_x', ylabel='Count'>

# %%
playerB_location_y = match_2['playerB_location_y'] - match_1['playerB_location_y']
sns.histplot(playerB_location_y)
# Out:
# <AxesSubplot:xlabel='playerB_location_y', ylabel='Count'>
